# %%
import pandas as pd

# %%
data = pd.read_csv("compensation data.csv")
data
# Out:
#        experience_coding  python_user  r_user  sql_user     most_used  \
# 0                    6.1         True   False      True  Scikit-learn
# 1                   12.3         True    True      True  Scikit-learn
# 2                    2.2         True   False     False           NaN
# 3                    2.7        False   False      True           NaN
# 4                    1.2         True   False     False  Scikit-learn
# ...                  ...          ...     ...       ...           ...
# 25968                1.9         True   False      True  Scikit-learn
# 25969                1.4         True   False     False       PyTorch
# 25970                0.0        False   False     False           NaN
# 25971                9.4         True   False      True  Scikit-learn
# 25972                0.0        False   False     False           NaN
#
#        compensation
# 0            124267
# 1            236889
# 2             74321
# 3             62593
# ...

# %%
data.head(6)
# Out:
#    experience_coding  python_user  r_user  sql_user     most_used  \
# 0                6.1         True   False      True  Scikit-learn
# 1               12.3         True    True      True  Scikit-learn
# 2                2.2         True   False     False           NaN
# 3                2.7        False   False      True           NaN
# 4                1.2         True   False     False  Scikit-learn
# 5                1.0         True   False     False       PyTorch
#
#    compensation
# 0        124267
# 1        236889
# 2         74321
# 3         62593
# 4         36288
# 5         61302

# %%
header = data.head(0)
header
# Out:
# Empty DataFrame
# Columns: [experience_coding, python_user, r_user, sql_user, most_used, compensation]
# Index: []

# %%
survey = pd.read_csv("compensation data.csv",skiprows=1, header = None)
survey
# Out:
#           0      1      2      3             4       5
# 0       6.1   True  False   True  Scikit-learn  124267
# 1      12.3   True   True   True  Scikit-learn  236889
# 2       2.2   True  False  False           NaN   74321
# 3       2.7  False  False   True           NaN   62593
# 4       1.2   True  False  False  Scikit-learn   36288
# ...     ...    ...    ...    ...           ...     ...
# 25968   1.9   True  False   True  Scikit-learn   15800
# 25969   1.4   True  False  False       PyTorch   62456
# 25970   0.0  False  False  False           NaN     923
# 25971   9.4   True  False   True  Scikit-learn   60609
# 25972   0.0  False  False  False           NaN     493
#
# [25973 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25973 entries, 0 to 25972
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       25973 non-null  float64
#  1   1       25973 non-null  bool
#  2   2       25973 non-null  bool
#  3   3       25973 non-null  bool
#  4   4       16835 non-null  object
#  5   5       25973 non-null  int64
# dtypes: bool(3), float64(1), int64(1), object(1)
# memory usage: 685.0+ KB

# %%
print(df.iloc[:, 5])
# Out:
# 0        124267
# 1        236889
# 2         74321
# 3         62593
# 4         36288
#           ...
# 25968     15800
# 25969     62456
# 25970       923
# 25971     60609
# 25972       493
# Name: 5, Length: 25973, dtype: int64

# %%
print(df.iloc[:, 5].tolist())
# Out:
# [124267, 236889, 74321, 62593, 36288, 61302, 68984, 18858, 55418, 614, 70564, 55525, 61005, 2846, 21, 14699, 2110, 620, 73527, 6992, 22311, 1377, 69174, 117636, 65937, 27856, 903, 50501, 482, 70407, 8690, 114648, 73454, 8075, 59151, 70112, 70183, 64502, 2521, 63616, 59849, 31516, 18582, 4187, 64405, 114807, 632, 61157, 1194, 28955, 56553, 75177, 28009, 67074, 50059, 7624, 74321, 671, 837, 2011, 62937, 685, 41615, 52572, 51856, 411, 152, 8181, 2708, 55041, 68412, 6141, 3979, 3760, 57465, 3864, 488487, 24393, 68624, 70796, 236889, 57861, 21055, 59167, 55882, 73802, 21206, 79803, 73043, 268191, 14298, 68805, 56003, 73664, 434, 52109, 10284, 43906, 67971, 58465, 64488, 7709, 1957, 4131, 26022, 29926, 62593, 109543, 107644, 1047, 59909, 68344, 54427, 70930, 50835, 14151, 11681, 71808, 70991, 31626, 52416, 288146, 65143, 34866, 186, 60065, 40336, 115654, 431, 59814, 45413, 4196, 55751, 61912, 49478, 29139, 67272, 70264, 264, 14853, 55482, 26, 250, 66025, 55906, 63754, 86855, 63242, 70448, 
# ...

# %%
python_users = data["python_user"].sum()
r_users = data["r_user"].sum()
sql_users = data["sql_user"].sum()

# %%
print(python_users)
print(r_users)
print(sql_users)
# Out:
# 21860
# 5335
# 10757

# %%
experience = df.iloc[:, 0].tolist()
compensation = df.iloc[:, -1].tolist()

# %%
min(experience)
# Out:
# 0.0

# %%
max(experience)
# Out:
# 30.0

# %%
sum(compensation)/len(compensation)
# Out:
# 53252.81696377007

# %%
Range = [0, 5, 10, 15, 20, 25, float("inf")]
cat = ["< 5 years", "5 - 10 years", "10 - 15 years", "15 - 20 years", "20 - 25 years", "25+ years"]


data["category"] = pd.cut(data["experience_coding"], bins=Range, labels=cat, right=False)

# %%
data
# Out:
#        experience_coding  python_user  r_user  sql_user     most_used  \
# 0                    6.1         True   False      True  Scikit-learn
# 1                   12.3         True    True      True  Scikit-learn
# 2                    2.2         True   False     False           NaN
# 3                    2.7        False   False      True           NaN
# 4                    1.2         True   False     False  Scikit-learn
# ...                  ...          ...     ...       ...           ...
# 25968                1.9         True   False      True  Scikit-learn
# 25969                1.4         True   False     False       PyTorch
# 25970                0.0        False   False     False           NaN
# 25971                9.4         True   False      True  Scikit-learn
# 25972                0.0        False   False     False           NaN
#
#        compensation       category
# 0            124267   5 - 10 years
# 1            236889  10 - 15 years
# ...

# %%
data.to_csv('updated_data.csv', index=False)
