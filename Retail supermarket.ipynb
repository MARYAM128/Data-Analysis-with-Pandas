# %%
import pandas as pd

# %%
data = pd.read_csv("retail supermarket.csv")
data
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
data.shape
# Out:
# (9994, 13)

# %%
data.shape[0]
# Out:
# 9994

# %%
data.shape[1]
# Out:
# 13

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
data.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %%
data.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
data.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %%
data.tail(10)
# Out:
#            Ship Mode    Segment        Country         City       State  \
# 9984  Standard Class   Consumer  United States   Long Beach    New York
# 9985  Standard Class   Consumer  United States   Long Beach    New York
# 9986  Standard Class   Consumer  United States  Los Angeles  California
# 9987  Standard Class  Corporate  United States       Athens     Georgia
# 9988  Standard Class  Corporate  United States       Athens     Georgia
# 9989    Second Class   Consumer  United States        Miami     Florida
# 9990  Standard Class   Consumer  United States   Costa Mesa  California
# 9991  Standard Class   Consumer  United States   Costa Mesa  California
# 9992  Standard Class   Consumer  United States   Costa Mesa  California
# 9993    Second Class   Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9984        11561   East  Office Supplies       Labels   31.500        10
# ...

# %%
data.head(8)
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 5  Standard Class   Consumer  United States      Los Angeles  California
# 6  Standard Class   Consumer  United States      Los Angeles  California
# 7  Standard Class   Consumer  United States      Los Angeles  California
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# ...

# %%
#data.loc[row_label, coloumn_label]
data.loc[2]
# Out:
# Ship Mode          Second Class
# Segment               Corporate
# Country           United States
# City                Los Angeles
# State                California
# Postal Code               90036
# Region                     West
# Category        Office Supplies
# Sub-Category             Labels
# Sales                     14.62
# Quantity                      2
# Discount                    0.0
# Profit                   6.8714
# Name: 2, dtype: object

# %%
data.loc[2,"Postal Code"]
# Out:
# 90036

# %%
#data.iloc[row_index, column_index]
data.iloc[2]
# Out:
# Ship Mode          Second Class
# Segment               Corporate
# Country           United States
# City                Los Angeles
# State                California
# Postal Code               90036
# Region                     West
# Category        Office Supplies
# Sub-Category             Labels
# Sales                     14.62
# Quantity                      2
# Discount                    0.0
# Profit                   6.8714
# Name: 2, dtype: object

# %%
data.iloc[2,5]
# Out:
# 90036

# %%
data.loc[2:10]
# Out:
#          Ship Mode    Segment        Country             City       State  \
# 2     Second Class  Corporate  United States      Los Angeles  California
# 3   Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4   Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 5   Standard Class   Consumer  United States      Los Angeles  California
# 6   Standard Class   Consumer  United States      Los Angeles  California
# 7   Standard Class   Consumer  United States      Los Angeles  California
# 8   Standard Class   Consumer  United States      Los Angeles  California
# 9   Standard Class   Consumer  United States      Los Angeles  California
# 10  Standard Class   Consumer  United States      Los Angeles  California
#
#     Postal Code Region         Category Sub-Category      Sales  Quantity  \
# 2         90036   West  Office Supplies       Labels    14.6200         2
# 3         33311  South        Furniture       Tables   957.5775         5
# ...

# %%
data.iloc[2:10]
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 5  Standard Class   Consumer  United States      Los Angeles  California
# 6  Standard Class   Consumer  United States      Los Angeles  California
# 7  Standard Class   Consumer  United States      Los Angeles  California
# 8  Standard Class   Consumer  United States      Los Angeles  California
# 9  Standard Class   Consumer  United States      Los Angeles  California
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
# ...

# %%
data.iloc[2:10,:7]
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 5  Standard Class   Consumer  United States      Los Angeles  California
# 6  Standard Class   Consumer  United States      Los Angeles  California
# 7  Standard Class   Consumer  United States      Los Angeles  California
# 8  Standard Class   Consumer  United States      Los Angeles  California
# 9  Standard Class   Consumer  United States      Los Angeles  California
#
#    Postal Code Region
# 2        90036   West
# 3        33311  South
# 4        33311  South
# 5        90032   West
# 6        90032   West
# 7        90032   West
# 8        90032   West
# 9        90032   West

# %%
data.iloc[2:10,7]
# Out:
# 2    Office Supplies
# 3          Furniture
# 4    Office Supplies
# 5          Furniture
# 6    Office Supplies
# 7         Technology
# 8    Office Supplies
# 9    Office Supplies
# Name: Category, dtype: object

# %%
data.loc[2:10,:"Region"]
# Out:
#          Ship Mode    Segment        Country             City       State  \
# 2     Second Class  Corporate  United States      Los Angeles  California
# 3   Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4   Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 5   Standard Class   Consumer  United States      Los Angeles  California
# 6   Standard Class   Consumer  United States      Los Angeles  California
# 7   Standard Class   Consumer  United States      Los Angeles  California
# 8   Standard Class   Consumer  United States      Los Angeles  California
# 9   Standard Class   Consumer  United States      Los Angeles  California
# 10  Standard Class   Consumer  United States      Los Angeles  California
#
#     Postal Code Region
# 2         90036   West
# 3         33311  South
# 4         33311  South
# 5         90032   West
# 6         90032   West
# 7         90032   West
# 8         90032   West
# 9         90032   West
# ...

# %%
data1= pd.read_csv("retail supermarket.csv", index_col = 1)
data1
# Out:
#                 Ship Mode        Country             City       State  \
# Segment
# Consumer     Second Class  United States        Henderson    Kentucky
# Consumer     Second Class  United States        Henderson    Kentucky
# Corporate    Second Class  United States      Los Angeles  California
# Consumer   Standard Class  United States  Fort Lauderdale     Florida
# Consumer   Standard Class  United States  Fort Lauderdale     Florida
# ...                   ...            ...              ...         ...
# Consumer     Second Class  United States            Miami     Florida
# Consumer   Standard Class  United States       Costa Mesa  California
# Consumer   Standard Class  United States       Costa Mesa  California
# Consumer   Standard Class  United States       Costa Mesa  California
# Consumer     Second Class  United States      Westminster  California
#
#            Postal Code Region         Category Sub-Category     Sales  \
# Segment
# ...

# %%
data.iloc[[2,5,8,9]]
# Out:
#         Ship Mode    Segment        Country         City       State  \
# 2    Second Class  Corporate  United States  Los Angeles  California
# 5  Standard Class   Consumer  United States  Los Angeles  California
# 8  Standard Class   Consumer  United States  Los Angeles  California
# 9  Standard Class   Consumer  United States  Los Angeles  California
#
#    Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 2        90036   West  Office Supplies       Labels   14.620         2
# 5        90032   West        Furniture  Furnishings   48.860         7
# 8        90032   West  Office Supplies      Binders   18.504         3
# 9        90032   West  Office Supplies   Appliances  114.900         5
#
#    Discount   Profit
# 2       0.0   6.8714
# 5       0.0  14.1694
# 8       0.2   5.7825
# 9       0.0  34.4700

# %%
data.loc[[2,10],["Segment","Category"]]
# Out:
#       Segment         Category
# 2   Corporate  Office Supplies
# 10   Consumer        Furniture

# %%
data
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
data["City"]
# Out:
# 0             Henderson
# 1             Henderson
# 2           Los Angeles
# 3       Fort Lauderdale
# 4       Fort Lauderdale
#              ...
# 9989              Miami
# 9990         Costa Mesa
# 9991         Costa Mesa
# 9992         Costa Mesa
# 9993        Westminster
# Name: City, Length: 9994, dtype: object

# %%
data.head(1)
# Out:
#       Ship Mode   Segment        Country       City     State  Postal Code  \
# 0  Second Class  Consumer  United States  Henderson  Kentucky        42420
#
#   Region   Category Sub-Category   Sales  Quantity  Discount   Profit
# 0  South  Furniture    Bookcases  261.96         2       0.0  41.9136

# %%
data[["Country","Postal Code","Category"]]
# Out:
#             Country  Postal Code         Category
# 0     United States        42420        Furniture
# 1     United States        42420        Furniture
# 2     United States        90036  Office Supplies
# 3     United States        33311        Furniture
# 4     United States        33311  Office Supplies
# ...             ...          ...              ...
# 9989  United States        33180        Furniture
# 9990  United States        92627        Furniture
# 9991  United States        92627       Technology
# 9992  United States        92627  Office Supplies
# 9993  United States        92683  Office Supplies
#
# [9994 rows x 3 columns]

# %%
data[["Country","Postal Code","Category"]].head()
# Out:
#          Country  Postal Code         Category
# 0  United States        42420        Furniture
# 1  United States        42420        Furniture
# 2  United States        90036  Office Supplies
# 3  United States        33311        Furniture
# 4  United States        33311  Office Supplies

# %%
data.drop("Postal Code", axis = 1)
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
data
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
data.drop(9993, inplace = True)

# %%
data
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9988  Standard Class  Corporate  United States           Athens     Georgia
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
#
# ...

# %%
data.drop(9990, inplace = True)

# %%
data
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9987  Standard Class  Corporate  United States           Athens     Georgia
# 9988  Standard Class  Corporate  United States           Athens     Georgia
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
#
# ...

# %%
data2= pd.read_csv("retail supermarket.csv", header=None)

# %%
data2
# Out:
#                   0          1              2                3           4   \
# 0          Ship Mode    Segment        Country             City       State
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class   Consumer  United States        Henderson    Kentucky
# 3       Second Class  Corporate  United States      Los Angeles  California
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9990    Second Class   Consumer  United States            Miami     Florida
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993  Standard Class   Consumer  United States       Costa Mesa  California
# 9994    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
data3= pd.read_csv("retail supermarket.csv", header=1)
data3
# Out:
#         Second Class   Consumer  United States        Henderson    Kentucky  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class  Corporate  United States      Los Angeles  California
# 2     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States      Los Angeles  California
# ...              ...        ...            ...              ...         ...
# 9988    Second Class   Consumer  United States            Miami     Florida
# 9989  Standard Class   Consumer  United States       Costa Mesa  California
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
data["State"] == "Florida"
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4        True
#         ...
# 9987    False
# 9988    False
# 9989     True
# 9991    False
# 9992    False
# Name: State, Length: 9992, dtype: bool

# %%
data[data["State"] == "Florida"]
# Out:
#            Ship Mode      Segment        Country              City    State  \
# 3     Standard Class     Consumer  United States   Fort Lauderdale  Florida
# 4     Standard Class     Consumer  United States   Fort Lauderdale  Florida
# 43    Standard Class    Corporate  United States         Melbourne  Florida
# 231   Standard Class  Home Office  United States             Tampa  Florida
# 232   Standard Class  Home Office  United States             Tampa  Florida
# ...              ...          ...            ...               ...      ...
# 9818  Standard Class    Corporate  United States  Saint Petersburg  Florida
# 9819  Standard Class    Corporate  United States  Saint Petersburg  Florida
# 9820  Standard Class    Corporate  United States  Saint Petersburg  Florida
# 9821  Standard Class    Corporate  United States  Saint Petersburg  Florida
# 9989    Second Class     Consumer  United States             Miami  Florida
#
# ...

# %%
data["Category"].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
data[data["Category"]=="Technology"]
# Out:
#            Ship Mode    Segment        Country           City       State  \
# 7     Standard Class   Consumer  United States    Los Angeles  California
# 11    Standard Class   Consumer  United States    Los Angeles  California
# 19      Second Class   Consumer  United States  San Francisco  California
# 26      Second Class   Consumer  United States    Los Angeles  California
# 35       First Class  Corporate  United States     Richardson       Texas
# ...              ...        ...            ...            ...         ...
# 9983  Standard Class   Consumer  United States   Grand Rapids    Michigan
# 9986  Standard Class   Consumer  United States    Los Angeles  California
# 9987  Standard Class  Corporate  United States         Athens     Georgia
# 9988  Standard Class  Corporate  United States         Athens     Georgia
# 9991  Standard Class   Consumer  United States     Costa Mesa  California
#
#       Postal Code   Region    Category Sub-Category     Sales  Quantity  \
# ...

# %%
data[(data["State"] == "Florida")&(data["Category"]=="Technology")]
# Out:
#            Ship Mode      Segment        Country              City    State  \
# 235   Standard Class  Home Office  United States             Tampa  Florida
# 314   Standard Class    Corporate  United States  Saint Petersburg  Florida
# 385   Standard Class     Consumer  United States    Pembroke Pines  Florida
# 435   Standard Class     Consumer  United States      Jacksonville  Florida
# 633     Second Class     Consumer  United States             Miami  Florida
# ...              ...          ...            ...               ...      ...
# 8921  Standard Class    Corporate  United States      Coral Gables  Florida
# 8957     First Class     Consumer  United States           Hialeah  Florida
# 9138  Standard Class     Consumer  United States  Saint Petersburg  Florida
# 9276    Second Class    Corporate  United States      Delray Beach  Florida
# 9443  Standard Class  Home Office  United States      Jacksonville  Florida
#
# ...

# %%
data[(data["State"] == "Florida")|(data["Category"]=="Technology")]
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 7     Standard Class   Consumer  United States      Los Angeles  California
# 11    Standard Class   Consumer  United States      Los Angeles  California
# 19      Second Class   Consumer  United States    San Francisco  California
# ...              ...        ...            ...              ...         ...
# 9986  Standard Class   Consumer  United States      Los Angeles  California
# 9987  Standard Class  Corporate  United States           Athens     Georgia
# 9988  Standard Class  Corporate  United States           Athens     Georgia
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
#
# ...

# %%
data[(data["State"] == "Florida") & ~(data["Category"]=="Technology")]
# Out:
#            Ship Mode      Segment        Country              City    State  \
# 3     Standard Class     Consumer  United States   Fort Lauderdale  Florida
# 4     Standard Class     Consumer  United States   Fort Lauderdale  Florida
# 43    Standard Class    Corporate  United States         Melbourne  Florida
# 231   Standard Class  Home Office  United States             Tampa  Florida
# 232   Standard Class  Home Office  United States             Tampa  Florida
# ...              ...          ...            ...               ...      ...
# 9818  Standard Class    Corporate  United States  Saint Petersburg  Florida
# 9819  Standard Class    Corporate  United States  Saint Petersburg  Florida
# 9820  Standard Class    Corporate  United States  Saint Petersburg  Florida
# 9821  Standard Class    Corporate  United States  Saint Petersburg  Florida
# 9989    Second Class     Consumer  United States             Miami  Florida
#
# ...

# %%
data[(data["State"] == "Florida")| ~(data["Category"]=="Technology")]
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9982  Standard Class   Consumer  United States     Grand Rapids    Michigan
# 9984  Standard Class   Consumer  United States       Long Beach    New York
# 9985  Standard Class   Consumer  United States       Long Beach    New York
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
#
# ...

# %%
df = pd.DataFrame([[1, 2], [4, 5], [7, 8]],
                  index=['cobra', 'viper', 'sidewinder'],
                   columns=['max_speed','sheild'])
df
# Out:
#             max_speed  sheild
# cobra               1       2
# viper               4       5
# sidewinder          7       8
