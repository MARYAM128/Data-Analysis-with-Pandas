# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("data_set.csv")

# %%
df
# Out:
#       invoice_no      invoice_date customer_id  gender  age         category  \
# 0        I138884   10/30/2016 9:58     C241288  Female   28         Clothing
# 1        I317333   10/30/2016 9:58     C111565    Male   21            Shoes
# 2        I127801   10/30/2016 9:58     C266599    Male   20         Clothing
# 3        I173702   10/30/2016 9:58     C988172  Female   66            Shoes
# 4        I337046   10/30/2016 9:59     C189076  Female   53            Books
# ...          ...               ...         ...     ...  ...              ...
# 99452    I219422  11/15/2016 12:43     C441542  Female   45         Souvenir
# 99453    I325143  11/15/2016 12:43     C569580    Male   27  Food & Beverage
# 99454    I824010  11/15/2016 12:44     C103292    Male   63  Food & Beverage
# 99455    I702964  11/15/2016 12:44     C800631    Male   56       Technology
# 99456    I232867  11/15/2016 12:44     C273973  Female   36         Souvenir
#
# ...

# %% [markdown]
# #QUESTION NO 1

# %%
df.isnull().sum()
# Out:
# invoice_no                0
# invoice_date              0
# customer_id               0
# gender                    0
# age                       0
# category                  0
# quantity                  0
# selling_price_per_unit    0
# cost_price_per_unit       0
# payment_method            0
# region                    0
# state                     0
# shopping_mall             0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 99452    False
# 99453    False
# 99454    False
# 99455    False
# 99456    False
# Length: 99457, dtype: bool

# %% [markdown]
# There are no missing values and duplicate rows

# %%
df.duplicated().to_list()
# Out:
# [False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
# ...

# %% [markdown]
# #QUESTION NO 2

# %%
df["Total Sales"] = df['quantity'] * df['selling_price_per_unit']

# %%
df.head()
# Out:
#   invoice_no     invoice_date customer_id  gender  age  category  quantity  \
# 0    I138884  10/30/2016 9:58     C241288  Female   28  Clothing         5
# 1    I317333  10/30/2016 9:58     C111565    Male   21     Shoes         3
# 2    I127801  10/30/2016 9:58     C266599    Male   20  Clothing         1
# 3    I173702  10/30/2016 9:58     C988172  Female   66     Shoes         5
# 4    I337046  10/30/2016 9:59     C189076  Female   53     Books         4
#
#    selling_price_per_unit  cost_price_per_unit payment_method region  \
# 0                 1500.40             1425.380    Credit Card  South
# 1                 1800.51             1620.459     Debit Card  South
# 2                  300.08              295.060           Cash   West
# 3                 3000.85             2900.765    Credit Card  South
# 4                   60.60               45.450           Cash  South
#
#         state   shopping_mall  Total Sales
# 0    Kentucky          Kanyon      7502.00
# ...

# %% [markdown]
# #QUESTION No 3

# %%
age_above_60 = (df["age"] > 60).sum()
print(age_above_60 )
# Out:
# 17169

# %% [markdown]
# #QUESTION No 4

# %%
df["customer_id"].nunique()
# Out:
# 99457

# %%
df.shape
# Out:
# (99457, 14)

# %% [markdown]
# The number of unique customer_id entries is equal to the number of rows in  DataFrame,
# it means that each customer appears only once, indicating that there are no multiple purchases.

# %% [markdown]
# #QUESTION NO 5

# %%
gender_counts = df['gender'].value_counts()
print(gender_counts)
# Out:
# gender
# Female    59482
# Male      39975
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6, 6))
gender_counts.plot(kind='pie', autopct='%1.1f%%', startangle=90, colors=['#66b3ff','#ff99cc'])
plt.title('Gender Distribution of Customers')
plt.ylabel('')
plt.show()

# %% [markdown]
# #QUESTION NO 6

# %%
category_counts = df['category'].value_counts()
category_counts
# Out:
# category
# Clothing           34487
# Cosmetics          15097
# Food & Beverage    14776
# Toys               10087
# Shoes              10034
# Souvenir            4999
# Technology          4996
# Books               4981
# Name: count, dtype: int64

# %%
least_popular = category_counts.idxmin()
print("Least popular category:", least_popular)

# %% [markdown]
# #QUESTION NO 7

# %%
sales_volume = df.groupby('category')['quantity'].sum()
sales_volume
# Out:
# category
# Books               14989
# Clothing           103598
# Cosmetics           45501
# Food & Beverage     44281
# Shoes               30217
# Souvenir            14871
# Technology          15033
# Toys                30321
# Name: quantity, dtype: int64

# %%
highest_sales_volume = sales_volume.idxmax()
print(highest_sales_volume)
# Out:
# Clothing

# %% [markdown]
# #QUESTION NO 8

# %%
df["Total Cost"] = df['quantity'] * df['cost_price_per_unit']

# %%
df["Total Profit"] = df["Total Sales"] - df["Total Cost"]

# %%
df.head()
# Out:
#   invoice_no     invoice_date customer_id  gender  age  category  quantity  \
# 0    I138884  10/30/2016 9:58     C241288  Female   28  Clothing         5
# 1    I317333  10/30/2016 9:58     C111565    Male   21     Shoes         3
# 2    I127801  10/30/2016 9:58     C266599    Male   20  Clothing         1
# 3    I173702  10/30/2016 9:58     C988172  Female   66     Shoes         5
# 4    I337046  10/30/2016 9:59     C189076  Female   53     Books         4
#
#    selling_price_per_unit  cost_price_per_unit payment_method region  \
# 0                 1500.40             1425.380    Credit Card  South
# 1                 1800.51             1620.459     Debit Card  South
# 2                  300.08              295.060           Cash   West
# 3                 3000.85             2900.765    Credit Card  South
# 4                   60.60               45.450           Cash  South
#
#         state   shopping_mall  Total Sales  Total Cost  Total Profit
# ...

# %% [markdown]
# #QUESTION NO 9

# %%
invoice_quantities = df.groupby('invoice_no')['quantity'].sum()
invoice_quantities
# Out:
# invoice_no
# I100008    5
# I100014    5
# I100015    2
# I100024    3
# I100027    4
#           ..
# I999956    4
# I999959    4
# I999972    2
# I999973    1
# I999994    3
# Name: quantity, Length: 99457, dtype: int64

# %%
top_invoices = invoice_quantities.sort_values(ascending=False).head(10)
top_invoices
# Out:
# invoice_no
# I283443    15
# I293215    12
# I282789    12
# I115679    11
# I207205    10
# I353272    10
# I160221    10
# I286193     9
# I215578     8
# I246375     8
# Name: quantity, dtype: int64

# %% [markdown]
# #QUESTION NO 10

# %%
 df['payment_method'].value_counts()
# Out:
# payment_method
# Cash           44447
# Credit Card    34931
# Debit Card     20079
# Name: count, dtype: int64

# %%
 df['payment_method'].value_counts().idxmax()
# Out:
# 'Cash'

# %% [markdown]
# #QUESTION NO 11

# %%
df.groupby('region')['Total Sales'].sum()
# Out:
# region
# Central    58803471.74
# East       72280660.57
# South      40655491.64
# West       79825624.03
# Name: Total Sales, dtype: float64

# %% [markdown]
# #QUESTION NO 12

# %%
average_sale = df.groupby('shopping_mall')['Total Sales'].mean()
average_sale

# %%
average_sale.sort_values(ascending=False)
# Out:
# shopping_mall
# Zorlu Center        2573.248351
# Kanyon              2550.618396
# Mall of Istanbul    2543.276766
# Viaport Outlet      2523.835118
# Istinye Park        2523.186677
# Metropol AVM        2497.777108
# Metrocity           2485.030133
# Name: Total Sales, dtype: float64

# %% [markdown]
# #QUESTION NO 13

# %%
category_sales = df.groupby('category')['Total Sales'].sum()
category_profit = df.groupby('category')['Total Profit'].sum()

profit_margin = (category_profit / category_sales) * 100

sorted_profit_margin = profit_margin.sort_values(ascending=False)

sorted_profit_margin.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Profit Margins by Category')
plt.xlabel('Category')
plt.ylabel('Profit Margin (%)')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# #QUESTION NO 14

# %%
df.groupby(['region', 'payment_method']).size().unstack(fill_value=0)
# Out:
# payment_method   Cash  Credit Card  Debit Card
# region
# Central         10319         8140        4640
# East            12738         9817        5751
# South            7227         5698        3284
# West            14163        11276        6404

# %% [markdown]
# #QUESTION NO 15

# %%
df.groupby(['gender', 'category'])['Total Sales'].sum().unstack(fill_value=0)
# Out:
# category      Books     Clothing   Cosmetics  Food & Beverage        Shoes  \
# gender
# Female    489420.75  68260097.84  4068073.66        505322.60  39425167.30
# Male      345238.20  45754397.92  2728611.28        344233.37  27128284.17
#
# category   Souvenir  Technology        Toys
# gender
# Female    382867.20  34669950.0  2416046.08
# Male      252957.45  23230200.0  1564380.16
